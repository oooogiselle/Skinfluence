# %%
# !pip install google-api-python-client pandas

from googleapiclient.discovery import build
import pandas as pd
import time as time
from collections import Counter
import re
# Out:
# Requirement already satisfied: google-api-python-client in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.170.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-python-client) (2.40.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.30.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2023.5.7)
# Requirement already satisfied: pyasn1>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: numpy>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
API_KEY = 'AIzaSyDjJjXe3yfIpBWi5yyGW5IODUbBoIpVqUM'
youtube = build('youtube', 'v3', developerKey=API_KEY)

def search_youtube_with_stats(query, total_results=100):
    all_videos = []
    video_ids = []
    next_page_token = None
    results_per_page = 50
    fetched_results = 0

    while fetched_results < total_results:
        request = youtube.search().list(
            q=query,
            part='snippet',
            type='video',
            maxResults=results_per_page,
            pageToken=next_page_token
        )
        response = request.execute()

        for item in response['items']:
            if item['id']['kind'] != 'youtube#video':
                continue

            video_id = item['id']['videoId']
            video = {
                'video_id': video_id,
                'title': item['snippet']['title'],
                'description': item['snippet']['description'],
                'channel': item['snippet']['channelTitle'],
                'published': item['snippet']['publishedAt']
            }
            all_videos.append(video)
            video_ids.append(video_id)
            fetched_results += 1

            if fetched_results >= total_results:
                break

        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

        time.sleep(0.2)  # Small delay to avoid quota spikes

    # 🔁 Now fetch stats in batches of 50
    stats = []
    for i in range(0, len(video_ids), 50):
        ids = ",".join(video_ids[i:i+50])
        stats_response = youtube.videos().list(
            part="statistics",
            id=ids
        ).execute()

        for item in stats_response.get("items", []):
            stats.append({
                'video_id': item['id'],
                'views': item['statistics'].get('viewCount'),
                'likes': item['statistics'].get('likeCount'),
                'comments': item['statistics'].get('commentCount')
            })
        time.sleep(0.2)  # Optional pause

    # 🧩 Merge metadata and stats
    df_videos = pd.DataFrame(all_videos)
    df_stats = pd.DataFrame(stats)

    df_full = df_videos.merge(df_stats, on='video_id', how='left')

    return df_full

queries = [
    "innisfree green tea serum review",
    "innisfree no sebum powder wear test",
    "innisfree not sponsored review",
    "innisfree before and after",
    "innisfree skincare routine 2024",
    "is innisfree worth it",
    "innisfree vs cosrx",
    "innisfree volcanic clay mask review",
    "innisfree hydration test",
    "innisfree honest review",
    "why I stopped using innisfree",
    "innisfree eco-friendly beauty campaign",
    "innisfree"
]


all_results = []
for q in queries:
    df = search_youtube_with_stats(q, total_results=300)
    all_results.append(df)
    print(f"✅ {len(df)} videos fetched for query: {q}")

# Combine all into one DataFrame
combined_df = pd.concat(all_results, ignore_index=True)

# Convert numeric columns
for col in ['views', 'likes', 'comments']:
    combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce')

combined_df.to_csv("/Users/giselle/Desktop/Dartmouth/Skinfluence/data/youtube_etude.csv", index=False)
print("📦 All queries saved. Total videos:", combined_df.shape[0])
# Out:
# ✅ 334 videos fetched for query: innisfree green tea serum review
# ✅ 336 videos fetched for query: innisfree no sebum powder wear test
# ✅ 306 videos fetched for query: innisfree not sponsored review
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[14], line 91
#      89 all_results = []
#      90 for q in queries:
# ---> 91     df = search_youtube_with_stats(q, total_results=300)
#      92     all_results.append(df)
#      93     print(f"✅ {len(df)} videos fetched for query: {q}")
#
# Cell In[14], line 19, in search_youtube_with_stats(query, total_results)
#      11 while fetched_results < total_results:
#      12     request = youtube.search().list(
#      13         q=query,
#      14         part='snippet',
#    (...)
#      17         pageToken=next_page_token
#      18     )
# ---> 19     response = request.execute()
#      21     for item in response['items']:
#      22         if item['id']['kind'] != 'youtube#video':
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?q=innisfree+before+and+after&part=snippet&type=video&maxResults=50&pageToken=CMgBEAA&key=AIzaSyDjJjXe3yfIpBWi5yyGW5IODUbBoIpVqUM&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %%
combined_df.to_csv("/Users/giselle/Desktop/Dartmouth/Skinfluence/data/youtube_tarte.csv", index=False)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   video_id     3818 non-null   object
#  1   title        3818 non-null   object
#  2   description  3818 non-null   object
#  3   channel      3818 non-null   object
#  4   published    3818 non-null   object
#  5   views        3818 non-null   int64
#  6   likes        3640 non-null   float64
#  7   comments     3778 non-null   float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 238.8+ KB

# %%
combined_df.to_csv("/Users/giselle/Desktop/Dartmouth/Skinfluence/data/youtube_estee_lauder.csv", index=False)

# %%
def get_top_comments(video_id, max_results=50):
    comments = []
    next_page_token = None

    while len(comments) < max_results:
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=min(100, max_results - len(comments)),  # API max is 100
                textFormat="plainText",
                pageToken=next_page_token
            )
            response = request.execute()
        except Exception as e:
            print(f"Failed to fetch comments for {video_id}: {e}")
            break

        for item in response.get("items", []):
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comments.append(comment)
            if len(comments) >= max_results:
                break

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

        time.sleep(0.1)  # avoid quota spikes

    return comments

# %%
all_comments = {}

for video_id in df['video_id']:
    try:
        comments = get_top_comments(video_id, max_results=20)
        all_comments[video_id] = comments
        print(f"Fetched {len(comments)} comments for video {video_id}")
    except Exception as e:
        print(f"Failed to fetch comments for {video_id}: {e}")
    time.sleep(0.1)  # be kind to the API
# Out:
# Fetched 20 comments for video A50_AmSTdVE
# Fetched 20 comments for video GY90IvsNbvw
# Fetched 20 comments for video Xy4LPjPOQ_w
# Fetched 20 comments for video 4OawHDNzZW8
# Fetched 20 comments for video QWwxA2pKJVg
# Fetched 20 comments for video -0AT8YwD9Ow
# Fetched 20 comments for video th-SfqKeOVg
# Fetched 20 comments for video tPjEziErRNI
# Fetched 0 comments for video 01HygSG2EQ8
# Fetched 20 comments for video i4fxs5JLBvc
# Fetched 20 comments for video KbpMDe5LK1g
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 10
#       8 except Exception as e:
#       9     print(f"Failed to fetch comments for {video_id}: {e}")
# ---> 10 time.sleep(0.1)  # be kind to the API
#
# KeyboardInterrupt:

# %%
all_comments
# Out:
# {'8bGE4-t6vks': ['1.byoma cleanser\n2. Bubble cleaner\n3.buble slam dunk\n4.glow recipe due drops\n5.drunk elephant bronzing drops\n6.tower 28 toner',
#   'Pls pin me',
#   'y’all just called me poor in 50 ways…\n(this is a joke)',
#   'you both are buaettiful the way you are',
#   'My favorite skincare brand is Bubble, and here is my skincare routine! 😁 \n1. Bubble Fresh Start cleanser \n2. Bubble Water Slide serum \n3. Bubble Cloud Surf Moisturizer\n4. Bubble Solar Mate SPF \nP.S. I hoped u liked my skincare routine! ❤❤',
#   '🌛☀️☀️☀️☀️☀️',
#   'Utan, wow cool I wish we had that in Masterton',
#   'I love skincare❤❤❤😮😮😮😂😂😂',
#   'I WANT TO SEE A NIGHT 🌃 AND MORNING 🌄 ROUTINE ❤❤❤',
#   'What is your favorite Skincare product',
#   'My skin care routine \nFresh start bubble gel cleanser\nBubble mist bubble moisture gel and bubble soft moisture and way more skin care',
#   'I love you',
#   'I have a skin care routine too. I’m only a year older than Callie because I’m 17 and she is 16 and I entered your giveaway and I really hope I win.',
#   '🌜🌞',
#   'Do a sleepover video next',
#   'my skincare routine \n1byoma milky moisture cleanser\n2clou surf moisturizer\n3 bubble plus one spf',
#   '🌙☀️❤',
#   'My routine is first use the watermelon glow recipe toner then use the ordinary serum and last the drunk elephant purple moisterizer',
#   'My routine is first use the watermelon glow recipe toner then use the ordinary serum and last the drunk elephant purple moisterizer❤',
#   '☀️🌙'],
#  'U0svrc0TDQM': ['Hailey is so beautiful im jealous lol :)',
#   'É tanta coisa no rosto que fico tonta de tanta informação.....rsrsrs',
#   'she jhas no other job for whole day Besides doing her skincare in morning afternoon night. Her hair feels so neglected',
#   'Give me the money to buy your products. Thank you, Hailey❤',
#   "guys can we talk about that Hailey is the first one that came up with the make up independet brand like rare, r.e.m and other cane after, correct me if i'm wrong that's why I always going to choose her brand, love Rhode ❤ also she has the MOST beautiful hands ive ever seen in my entire life",
#   'Sorry but this is absurd!  Someone so young and obviously with no serious skin issues to use this incredible amount of products just to “prep” for makeup. It’s a miracle the makeup just all doesn’t slide off.',
#   'Her skin>>✨😭',
#   'chill and calm',
#   '❤❤❤❤❤❤',
#   'when it comes to skincare, i believe every word she says and every advice she gives.',
#   'hated by many defeated by none ly hailey',
#   'Her skin shiny beacause its so so oily',
#   'سلام زندگیم تیم شما ببندید من کاملا به شما اعتماد دارم شوهرت جاستین دوست داز❤',
#   'I will definitely try this.',
#   'Wearing accessories while skincare prep... Big turn off',
#   'Gorgeous',
#   'Hailey vous ne mettez jamais de sérum en soins ?',
#   'So pretty 😮\u200d💨',
#   'سلام زندگیم',
#   'I really love your skin'],
#  'Bw1ces4xiD4': ['Can I please get a pin??? I also love y’all',
#   'Actually, your lips are just\nChapped',
#   '❤❤❤❤❤',
#   'U are not braking out but your videos are amazing!',
#   'She got a ghost in her house. She better get out of the house.😂😂😂😂',
#   'I’ve been thinking about getting the Tatcha moisturizer….. is it worth it?????? Btw your literally so gorgeous!!!!!!!!',
#   'Hi the profile is my moms and i love you and kadi',
#   'hey my girl, the reason why u might be breaking out is the ordinary pink serum apparently it’s suppose to be bad for ur skin, and they put in a wrong ingredient ❤❤',
#   'Girly that’s way to much',
#   'Not trying to be rude but your skin could get more damaged or acne if you use 3 toners girl ❤❤',
#   'Girl thoses are the goldie drops or the bronzing drops',
#   'I love your channel! I’m new to skincare, your videos are helping me decide what to use! You guys are so pretty!',
#   'Don’t be so rough on ur skin I am a dermatologists so please be careful also no retinal rn please! ❤🎉😮😅😊',
#   'Do u even cleanse',
#   'i’m not trying to be like rude or anything, but I think that why you’re breaking out is because you’re not using a cleanser',
#   'Love this skincare routine! Pin???',
#   'You look like jojo siwa in a good way',
#   'The thing I happened to you came that’s happening to my camera',
#   "It's maybe you're a skincare you don't need skincare all you need is just water is soap that's all",
#   'Hi am I tried to buy the watermelon toner at Sephora and the worker there told me that it increases son by a lot so every day you have to put on sunscreen and two weeks after you run out of the bottle not trying to be rude or tell you what to do Though,'],
#  'Ev4englzDjo': ['Can you tell she likes yellow',
#   'isn’t vitamin c serum supposed to be kept in the fridge or am i thinking of something different?',
#   'New trend… CAT SKINCARE',
#   'I really hate shameless promo that isn’t obvious, because it just feels so much more deceitful and dishonest',
#   'Bro is raging',
#   'I feel like if your on vacation the single use towels and sponges could be helpful but the sponge looks like it would hurt so bad',
#   'Companies should stopusing plastic',
#   'Plz ask the girls to stop doing this tedious fillers',
#   'How to destroy your skin barrier. ☹️',
#   'Does anybody else get cringed and angry with the nail clacks on the product?',
#   'I I can’t with these hyper consumers making tons of plastic waste for their “routine” where they use the products incorrectly',
#   'Can i just note that those sponges are not supposed to be used once only.  They are made for beauty industry for a multiple client environment to avoid cross contamination and to give the client the knowledge fresh products are being used on each client.  They can be washed dried stacked in a container and used again folks.  They are not intended for personal care and overconsumption.',
#   'Why is everything single use',
#   'And then she presses her dirty cat against her face undoing all the cleaning she just did. Awesome',
#   'The kitty was curious',
#   '𝓦𝓱𝓪𝓽 𝓭𝓸𝓮𝓼 𝓽𝓱𝓲𝓼 𝓰𝓾𝔂 𝓮𝓿𝓮𝓷 𝓴𝓷𝓸𝔀 𝓵𝓲𝓴𝓮 𝓼𝓱𝓮 𝓬𝓪𝓷 𝓭𝓸 𝔀𝓾𝓽 𝓼𝓱𝓮 𝔀𝓪𝓷𝓽𝓼',
#   'OML SO MUCH SINGLE USE THE PLANET IS SCREAMING',
#   'im sorry this is impulsive but saying "dermatologist here" and breaking down every step of every act of the original creator seems soo money hungry. yes the original creator is overconsuming and doing it for the camera (duh) but this "dermatologist here" is just adding unnecessary commentary to make even more money off of this overconsumption, only further encouraging this kind of behavior lol',
#   "Do not you know how much germs are hands have your issue with single use the new stop using single use plastic don't recommend others if they are not want to. Do you know what's good for the skin you doesn't you know how much jobs a person have in your hand. Are you even a doctor",
#   'Bro. Chill it’s not gonna last for hundreds of years.'],
#  'HuZ9VvghR0w': ['The first one had me crying 😢',
#   'Can someone be r here',
#   'I have a question. do you have eyelashes ?😅😅',
#   '👏👏😏',
#   'That dae product is for your hair I think',
#   'So good girl❤❤',
#   'Hmmmm uhhhh',
#   'i actually was hurt when she was purposely not doing the skincare on purpose judging on the price',
#   'Gostei 👍 👍',
#   'Girlie dont waste :(',
#   'U have no lashes',
#   'FINALLY SOMEONE DOES IT RIGHT!',
#   'Guys  call knaby lame',
#   'That girl is doing it wrong. She’s putting skin care wrong. It’s because it’s not even on her face.',
#   '😩😩😩😩😩😩😩',
#   'U arent the ‘black sheep’ ur the ‘rainbow sheep’ ur so pretty outstanding and unique ❤️',
#   '😂😂😂😂❤❤',
#   'finally someone who can actually apply skincare',
#   'I finally found someone who knows how to properly apply skincare! 😃',
#   'Perfect⭐️✨'],
#  'GhPjx2dvPTg': ['He didn’t add anything helpful. Just saying “ok….ok”',
#   'ts buns',
#   'double cleansing literally changed my life if anyone is considering trying it out',
#   'She tripled cleansed, not double',
#   'Shouldn’t your serums go before the moisturiser tho',
#   "So, basically you're just selling expensive products?",
#   'whens the wedding?',
#   'Wait- not everyone has to double cleanse?! I thought if you wear sunscreen dc is a must?',
#   "Ah she's so beautiful",
#   'If everyone is using a sunscreen, as they should, then yes, everyone does indeed need to do a double cleanse.',
#   "Finally someone he's friends with 😭🙏",
#   'what are your thoughts on centella light cleansing oil and centella ampoule foam as a double cleansing duo??',
#   "what's her youtube??",
#   'I love your videos so much, but I would love even more if you could post the products through using (not the ridiculous ones) in the description 😊',
#   'Spf???',
#   "I thought it was gonna be a rage indicing routine but that's actually a real nice routine. Cicaplast is amazing though i prefer Cicabio by Bioderma now.",
#   'Her skin is so beautiful',
#   'Who needs double cleansing?',
#   'If you did any of the consumerism steps your pores would start drowning and filling with all that crap and then form a pimple. COMPLETE OPPOSITE OF WHAT WE WANT TO ACHIEVE. The pimples form for me if I use too much products or anything heavy. Serums my skin likes but I dont want a fur coat on my face so I try not to sleep with it unless its a toner',
#   'If I wear makeup, I WILL double cleanse'],
#  'BogoqKnfG-c': ['I’m so surprised there’s no glow recipe',
#   'Slay',
#   'Can u give you a tip Gosha and roll your face up cuz gravity, naturally pulls your face down I’m not hating im just trying to help',
#   'I think you should do something in the bath, but like purple edition',
#   '❤',
#   'I love pink \U0001fa77💖💕🌸',
#   '✨🌷',
#   'Me :let’s put on my skincare you: washes face before skincare',
#   'Can you send me the lip mask My address is 430 East Rittenhouse',
#   'Can you show your face please',
#   'I LOVE THIS CAN YOU DO Purple I LOVE YOU',
#   "I don't like pink I like maroon so plz maroon",
#   '❤❤❤❤❤😂',
#   'I love thisdsdd❤❤❤❤❤❤❤❤❤❤',
#   'Wow! My daughter would love this!\U0001fa77\U0001fa77\U0001fa77\U0001fa77',
#   '#wealllovepink🎀💖',
#   'the versed cleanser 😍💕',
#   '💅💅💅💅SO PREPPY💖💖💖💖💖💖💖',
#   '\U0001fa77\U0001fa77\U0001fa77',
#   'You have beautiful skin you don’t need that'],
#  'GvkCOLICemA': ["I highly recommend ANUA heartleaf cleansing oil & foaming cleanser! (I think she used their cleansing oil) I can't speak on how it works for acne prone skin but I have very sensitive skin & most products I've used in the past are very irritating to my skin. Ever since I started using ANUA (about 2mo ago) my skin has been less sensitive & more moisturized! (I owe that to my other skincare products too) but I'll never use another cleansing product again 💕",
#   'So satisfying ❤',
#   'Yeah right, if a mom with three small kids had that much time for herself, I would have done it, but just one step out of all those steps it would take me weeks or months to get time for 🙆🏻\u200d♀️',
#   'Pls use spf to protect yourself from UV 😊.',
#   'Idek why but girl with smalls red hormonal acne just look so good',
#   'Not the sugar scrub on the face 😭 only use chemical exfoliants on the face please 🙏',
#   'I feel her skin is irritated now',
#   'Did it work???',
#   'I have to try this',
#   'Hello? Where is the sunscreen',
#   'Am I the only one that remembers this girl from the British makeup',
#   "Try layering by adding the famous mix soothing essence for troubled skin! In Korea, it's famous for soothing and moisturizing makeup",
#   'K skincare 하지마!! 젊어보이는 건 한국인들의 특권이다.',
#   'Your skin looks a little redder than before',
#   'She wearing a freaking filter 😭 the pimples are a filter yall',
#   'LOVE ❤',
#   'I have hormonal acne and I really don’t know where to start! Any advice?',
#   "Nice video, I'm born in Vanlose, Denmark and thought it's interesting, I live in Canada today.",
#   'So do yall recommend that I stop my face products right now and buy all these. I struggle with mild hormonal acne!!',
#   'You’re so Pretty'],
#  'O0hrjBn3wXo': [],
#  'VzBAe1Yuimg': ['The prettiest eyes I’ve ever seen',
#   'She so pretty and omg the lashes and I know someone said that but why not say it again',
#   'So pretty ❤❤❤❤❤',
#   'what is the ball thing',
#   'the eye like DOOL !✨',
#   'Okay she’s beautiful 😍 I’m a girly’s girl',
#   'Girl u are STUNNING ❤❤❤',
#   'you are so cute❤',
#   'I’m tryna start something so, reply on my comment with your skincare routine and products if you have one or even your morning routine ! Here’s mine: \nFirst I start with some aloe Vera cleansing jelly with my scrub glove\nwash face and use any kind of cleansing wipe\nGo in with some Nivea moisturiser cream and rub in with wing motions going up cheekbones\nlet it soak in\nMassage in  sun screen or after sun (it sounds weird but trust me, it’s so soothing, it moisturises really well and makes your skin glow)\nScrub lips gently with hand gloves or CLEAN toothbrush \nApply lip balm (I use water Mellon cuz it’s tasty)\nOutfit\nHair\nMakeup \nOff to high school! ❤',
#   'الصراحة انتي كتير بتشبهيني',
#   'You are sooooo pretty.I love your eyelashes❤🤩🤩😘',
#   'Mu skin care routine\nWater, water, cold water',
#   'Your eyes are insane',
#   "Okay. We get it, you're rich. 🙄\nAll jokes aside, you're so pretty!!",
#   'U wash ur face but ur eyebrows are stick to the same place',
#   'THISE LASHES',
#   'What is the product that formed a mask on her skin?',
#   'Very badf😢',
#   'What mascara do u use I have kinda long lashes but I can’t find a mascara that actually makes my lashes long❤😂😅😊',
#   'STOP Why is she literally so pretty'],
#  'JJonTlZCHMg': ['I had to watch this again without reading the comments first...sorry girl🥴\nLoved, loved, LOVED this!!!! Thanks🎉🎉🎉\nOmg, that overnight mask!!!!❤❤❤❤',
#   'the hands giving man',
#   "Omg I've been following you two since I was 14, I'm 21 now and it's so awesome to see how you and Row have changed and how the channel has evolved. Love you guys !! 💖",
#   'Thank you for your honest review of the best K-beauty skincare products of 2024! I think the detailed explanation and honest review made it easier to choose the right product for my skin!',
#   'Cleansing wipes are so bad for the environment. Just use a cleanser or makeup removing cream instead.',
#   'I ❤❤❤ HaruHaru line is my favorite 😊',
#   'I Love a great Serum',
#   'Can someone tell me her skin type/the video is for which skin type,???😢😊',
#   'I forgot what was your skin type? Was it oily sensitive?',
#   'how does the haruharu barrier essence compare to the Rhode glazing milk (if you have tried it) are they similar?/which is thicker?',
#   'Hello from Brazil. I really Like yours videos. If possible,could you please explain someday how do use medicube age booster pro, the fistr step until the last with the correct products  for each program? I’ll really appreciate it. Thank you so much. 😊',
#   "Hello Felicia! 😊\n\nI really wanna try the Numbuzin sunscreen but my only concern is one ingredient it contains which is velvet deer extract. I've read some very negative things about it 🤔\n\nCould you please make a video talking about this ingredient? ❤",
#   'Who else knows mommy pig is having a baby, (LICH THIS HAS NOTHING TO DO WITH THIS DON’T JUDGE!!)',
#   'I love HaruHaru. one of the brands i repurchase all the time. and thanks to this channel. i started using their toner since they first introduced',
#   'Thanks for this great video. What does the onion fresh sunscreen smell like?',
#   'hey what do you recomend for clossed comedos ?',
#   'Do I need to use a Reedleshot serum in order to use the masks?',
#   'Heyy... fel❤\ni am an Indian annd new to skin care ... i have dry sensitive skin... Can i use madagascar centella 1004 light cleansing oilll and madagascar centella ampoule foam? Will these products suit mee? Or will it make my skin more dryerrrr.......',
#   'VT can have all my money',
#   'what happened to your voice damn'],
#  'XH-tvdtS1nk': ['AHHHH FIRSTTT CAN I GET A PIN MILKYYYY',
#   'Next can you do for 10 to 11 skin type is oily and prone to acne pls i love ur vids ❤😊',
#   'That Is Nice And You Should Avoid Of Making Skincare Mistakes,Okay?😂❤',
#   'is the brand, ma:nyo bad for young skin?',
#   'milky, can u do 13 year olds with acne prone skin/hormonal acne please? 💜🌸',
#   '8 year old pls',
#   'Filters😂',
#   'Do 10 to 13 pls pls I love ur vids',
#   '감사합니다! 한국 스킨케어 제품을 찾는 데 어려움을 겪고 있었어요!😊',
#   '10 year olds',
#   'Anua niacinamide+',
#   'Can we just add snail muccin as a essence in it',
#   'Make one for 13-14 years old!! Please i watch your videos everyday without missing a video!!',
#   'Why your skin yellow around lips 😮',
#   'I want money 😢',
#   'My skin is sensitive so can I use Dr athlea 345 cream. Kindly guide',
#   'Please do 11 years old',
#   '10 yr olds plsss😊',
#   'Thank you, I will try some products and wait for the result !!!',
#   'Skincare for 12 yr old please ❤❤'],
#  '6xXB0tXyBIM': ["Okay so I have a question...\nDo I need a facial cleanser I mean I wash my face when I bath? (I don't wear makeup) \nI'm asking cus I want to start take care extra of my skin so I wanna eliminate extra steps that are not necessary to me",
#   "This has been my PM routine for 7 months so far because I was tired of the bullsh!t skin trends and it's soooo good. Feels like going back to the simple 90s routines but with way better info and way better products. I guess I'll have time to worry about actives' percentages, routine steps and aging signs when I hit my mid 30s or something.",
#   'Sunscreen.',
#   "Omg now I know men's secrets!",
#   'Uhhh… putting your hair up and using headband is Mf’n step alright? It’s almost like you’re unhappy he’s not coming in for a treatment $$$. Pick a lane.',
#   'this is my routine for night and in mornin gglow screen',
#   'It’s been a while since I felt thirsty 🤣',
#   'My 3 step skincare routine \n1. wash face (i’m not fond of cleansers because it just seems like you’re rubbing stuff into your face and you aren’t getting it off, you’re just rubbing that dirt/makeup into your face)\n2. stridex (this is an acne removal product, it works really well but it does dry out your skin)\n3. moisturizer',
#   'no because this is the same thing i do everyday ☠️',
#   'My routine is fancier, I also use spf. (But basically we have equally simple routines)',
#   'Everyone talks about Cerave what about Cetaphil?',
#   'he’s so hot he’s so hot help',
#   'What cera ve cleanser is perfect for oily skin and large pores??? Especially bcz of school air',
#   'This is legit my routine (expect I use a vitamin c moisturizer before my regular one cause I have bad hyperpigmentation) other than that just some Vaseline and done!! Cleansing and moisturizing defs do the job for me',
#   'Men just made us girlies angry at how fast he did it.',
#   'This is literally my exact routine, except I also wear sunscreen every day (rain or shine).',
#   'If my man used that headband around the house I would marry him! (I’m too single tho)',
#   'these are perfect if ur gay',
#   'Wait, do people not wet their skin before cleansing?!?',
#   'What would you recommend for eczema skin?'],
#  'ebG4iGkI4zM': ['Does she only take the makeup off her cheeks....',
#   'why shouldn’t you touch the dropper to your face?',
#   'Why do they have to tap EVERYTHING?!?!?!',
#   'i always ask myself why we cant touch the dropper to our face 😭',
#   'there’s a dentist on here who read her to filth as she doesn’t actually brush her teeth. i can’t look at her without cringing. her gums were soooooo inflamed',
#   "This lady's lips bother me😂😂 they look so baloony",
#   'hella filter',
#   'using brow serum on obviously fake brows is insane',
#   'She has used so much lip fillers, it looks very weird now, and damager her skin barrier obviously just for views and attention',
#   'Did you see the filter glitch?',
#   'just look at her cheeks with no makeup so beautiful',
#   'It’s the lady with the gums from\n the dentists video lol',
#   'the products are good but wth do u have all these tools',
#   'Throughout the whole vid I was like “girl... ur forehead... it’s oily and it can’t make the most acne”',
#   'she can di what she wnats get a life and stop judging',
#   "As someone that's been shaving their face for like 20 years if I shaved my face then put all of that on my skin, it would be incredibly irritated. I cant even imagine",
#   'Y do you care',
#   'Half assed, heavily filtered "skincare" video... sigh...',
#   'Love the blonde hair',
#   'In my opinion the girl is not looking the best'],
#  'XQoyU43dLbA': ['YELLOW TEAM\n👇',
#   'Purple please',
#   'Can you do blue 🙏',
#   'Ummmm OOOO can you do purple skincare?????❤❤❤❤',
#   'Try purple',
#   'Black',
#   '💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚💚',
#   '😂😢😮😅😊JELÖU',
#   'You look like my big brother',
#   'Team purple',
#   'Blue',
#   '🥏🏸🎽Blue',
#   'Blue or green',
#   'Yellow please 🐤🐥🐣🐝🌻🌼🌟⭐️💫✨️✴️☄️🍌🍋🌽🧀\U0001fad7🧃🌅',
#   'Sky, blue and violet',
#   'Blue!! 💙💙',
#   'You are saying it Wrong',
#   'It’s not byoma gel cleanser it’s gel cream but I still love your vids obvi',
#   'Gren please🐸🦖🦎🐢🐍🌳🌲🎾🪀',
#   'Blue'],
#  '_Kv3jDo7cqA': ['💜💜💜💜',
#   'I love \U0001fa75\U0001fa75\U0001fa75\U0001fa75💙💙💙💙',
#   'do. Koromi. 😢😢😊😊😊❤❤❤',
#   'Black 🎉🎉',
#   "Au grand je vous remercie par avance pour votre aide cordialement mme le temps de faire un point sur la page d'accueil de 🤣 de faire une",
#   'Pink',
#   '🖤🖤 skincare',
#   'I know it.',
#   'Rain bow',
#   '🧡🧡🧡🧡🧡🧡🧡🧡',
#   '💙💙💙💙',
#   'My favorite colour is blue',
#   'Please  rainbow  skincare',
#   'Black',
#   'Black please😢😊',
#   'Wow......!so prety❤',
#   'Plese purple 💜💜',
#   'red',
#   'Purple 💜💜💜',
#   'Pink❤'],
#  'whN-3jBclXA': ['Bro you need to link the videos and creators. I wanna know the products and listen to HER 😭 and you over here commenting for nothing. at least put it in the description.',
#   'what lip balm is that?',
#   "She's gorrrrgggeous!",
#   'Her baby hairs are baby hair-ing 😭😭',
#   "First time he's not getting mad at the craziness of the routine 😂 first serious influencer then 😂",
#   'Don’t forget your neck area.',
#   'This is literally the first one I’ve seen that does use 3 million different things for each eyebrow',
#   'That it❤',
#   'Can someone tell me the name of the sunscreen and lip balm she used? Thanks',
#   'Finally he wasn’t being negative',
#   "What's the difference between hydrating serum and moisturized? Are hydration and moisturizing different things???",
#   "It's always the ones speaking",
#   'Anyone know the sunscreen she uses?',
#   'Idk much about skincare, why do you need a hydrating+calming serum AND a moisturizer, one after the other? They sound like they do the same thing??',
#   'But her hair tho <swoon>',
#   'Her skin is so good!!!!!!!! 😭✋✨',
#   'Does anyone know the name of all the products she used in the video now i kinda want to by some 😭✋',
#   'You have to let those dry first before putting on the next, right?',
#   'Too much on her face\n\nIf I do more than soap and water, my face will become greasier than a slice of pizza. \n\nAlso her skin is so "flawless" because of genetics',
#   'Do u know her channel?'],
#  'YuCVauEgbVo': ['How old is Elisa',
#   'She’s like seven little girls shouldn’t be wearing skin care. They are too young their parents so stop getting them stuff like that. At least get two or one of them. Your skin is perfect. If anyone thinks I’m right, please like and I’m gonna like my own comment because people don’t like mine and please can you guys stop using skincare you are too young.❤❤',
#   'She’s like seven little girls shouldn’t be wearing skin care. They are too young their parents so stop getting them stuff like that. At least get two or one of them. Your skin is perfect. If anyone thinks I’m right, please like and I’m gonna like my own comment because people don’t like mine and please can you guys stop using skincare you are too young.❤❤',
#   'Scrolling to the next video and it being one of those skincare for 7 year old vids with water and stuff I went strait back up to comment 🤣',
#   "Tbh I think mascara when is in occasion but I'm morning girl she don't need it (aka I'm sry I; I'm being rude but is true plz understand me ty bye y'all xx)",
#   'Spoilt',
#   'I love skin care❤️',
#   'No hate!!!! but she is 7 and I think it’s so cute and fun to have a cute spa day with her elder sister and do skincare then for fun but don’t make it an everyday because although it’s popular it kills your skin and makes your skin bad. It’s super cute for her too love it but get her stuff that can still be enjoyable/ preppy but age appropriate e.g. sunscreen, Sol de janero, Lippies! Things that she can still look forward too and save her money for but still have her perfect skin and enjoy her youth while still young!!❤',
#   'She’s so cute!! ❤',
#   "Skincare.tips😊\nDon't start at.young age problely start at 9 \nMake sure u don't put perfume or makeup before more skincare\nMake sure you don't rub ur face on the towel u should tap\nAlso use some moisturiser too\nTry use vegan skincare it is better for ur skin some vegan skincare is still popular like bubble byoma glow recipe\nAND OFC SLAYYYYYYYY",
#   'Try ever eden and sold in Ginera isn’t a skincare item, it’s perfume',
#   'She’s 7 and I’m like 12 and I only use moisturizer and pimple cream and sun cream and a kid definitely does not need all that',
#   'I feel like right now all she needs is a gentle cleanser, a moisturizer, and sunscreen. But when she gets to like pre-teens and teens and you start getting acne, that’s a whole different story.',
#   'I don’t think there’s anything THAT wrong with her using skincare but I would avoid makeup like mascara and use a gentle cleanser and a moisturiser if she wants to u skincare she ATLEAST needs a moisturiser',
#   'No hate I love your care for ur skin and ur skin care routine but the only skin care you need at this age is water',
#   'My skin routine as a 12-10yo\nJelly cleanser \nBubble moisturizer \nDrunk elephant sunscreen \nThat’s it and yes, I have permission to put it on because it’s good for my skin😊',
#   'When I was little, I didn’t even use any of those products. All my mom allowed me was to get me lip balm, and body wash and hair wash for kids.',
#   'Not tryna hate but she doesn’t need skincare she’s 7 her skin is already pretty',
#   "She doesn't know how to talk",
#   'Why yall think sdj is skincare its a body mist'],
#  'Td0W9kFrfao': ['I wish I could use half the amount of shit she’s using. My eczema skin care routine involves two steps',
#   'If you die how are you going to have it if your in heaven❤?',
#   'I was scrolling on asmr and I scrolled and heard him screaming “ALL PINK SKINCARE ROUTINE” r.i.p headphone users like me no hate',
#   '🌈🌈🌈🌈🌈🌈🌈🌈🌈🌈🌈🇽🇰🇽🇰🇽🇰🇽🇰🇽🇰🇽🇰🇫🇷🇫🇷🇫🇷🇫🇷🌹🌹🌹',
#   '❤',
#   "Ik its her own money and her own choice to have that much skincare...but that is def overconsumption, im not hating but its where you get so much stuff that you won't even get to finish all of them before they expire and then you have to trash all of that waste of products and money and its just bad for the environment.",
#   'Why do you scream in every single video?',
#   'She was not shaving her under eye she was putting on eye cream',
#   'Hi mate im 8 and I’ve never ever hav been pined and I would love it your my favorite YouTuber in the world and your skin is so shinny ❤❤❤ love your vids and coments Apis PLAESE please plaese pin me ❤❤',
#   'Pick is my favorite too',
#   'Omg I have these pinks!!!! So cute!!! I love them so much',
#   'Omg 😮',
#   'Never sell your soul\U0001fae1',
#   'Purple',
#   "Im always liking matts post because of his energy, i could'nt care less about skincare!!!",
#   'You can tell that he’s rushing because of videos going so fast',
#   'If you sell your souls to have that skin you can have skin blah blah blah',
#   'You all ready have beautiful skin',
#   'I love he talks good about good about her',
#   'Matt:omg I would die to have them\nMe:but you would already be dead👀'],
#  'xN7L8dFJ1vI': ['The make-up remover is Clinique I think that ❤',
#   'Looks horrible but is actually ReAlLy AmAzInG💖💖💖💖💖💖💖💋💋💋💋💋',
#   'I have that the same one and same color',
#   'The makeup remover could be drunk elephant beste jell cleanser or the glow recipe avocado cleanser',
#   'I also use cerave',
#   'Mack a video with you sister',
#   "I'm mean slay",
#   'What brand does the makeover remover from?\n😂😂😂',
#   'I wish CeraVe worked for me. I hate having sensitive skin!! 😭',
#   'Grrrrl that’s a dollar tree bag😂',
#   'Cool',
#   'that says dollar tree',
#   'Can we see her putting on the skincare, or does she not like being on camera',
#   'Pink thing you have my mom literally has it and that thing that you put on your face, it makes your skin super soft and I literally have that so you probably got the same thing that my mom got from the store did you get it first or did my mom get it firstBy the way my name is Charlie but everybody calls me Charlotte I’m joking. Everybody calls me Charlie, but my real name is Charlotte.',
#   'Girl u aways steal😂',
#   'I have the same thing you fill with water, and I’m just not figuring out that’s how u fill it up?!?',
#   "I have some CeraVe and it's good",
#   "That's a ice roller 😂",
#   'The rong bag 🛍️',
#   'The first one looks like hand sanitizer'],
#  'TsQGQ_9JtQ0': ["Good morning & thanks for watching! There are so many questions on using COPPER PEPTIDES with VITAMIN C so I wanted to answer here! I did a detailed video on that and IMHO they're fine to use together in most cases but for all the details & research please check out my video on it: https://youtu.be/UEvlM6u8D_M\nAlso, lots of questions on the Estriol cream: It cost $55 & the compounding pharmacy is called skinmedicinals.com, I'm using it on my neck to do the testing so I can isolate it from any other ingredients. I will eventually use it on my face if it pans out. Have a great weekend! xo ~a. 💜",
#   'I have been following you for years and use Curology. Should I switch to the Agency? What is the difference?',
#   'Hi Angie, I am also in my 40s and started using Agency long time ago. I reached the maximum Tertinoin percentage provided by Agency already do I keep using the same concentration ? Shouldn’t we keep increasing the percentage',
#   'Can you recommend a good scrub for the body that I can use in the shower? Also, what body shower gel you recommend or soap? I find most drying my skin . Thank you.',
#   'I use Tretinoin O.05% everyday, now my skin is flaky everyday and looks so ugly, What should I do?',
#   "I bought a nuface and sent it back, I did not feel anything,  shouldn't you feel something?",
#   'I would love to see the cost of alllllll these products and gadgets added up!',
#   'I am still using the agency that you recommended years ago. Is there a reason I should switch to the Agency??',
#   "61 here :)  TO Argeriline is excellent!  It prolongs your wrinkles from forming or from getting worse (depending on your severity).  I've been using this for 10 years on and off but for the last 5 years I have used religiously.  About a year ago I stopped using this at night and wrinkles began forming on my forehead within a month but I didn't go back to BID.  Took me 3-6 months to return to BID.  Huge mistake.  I've been watching youtube since 2018 but I started with makeup even though I don't wear much and came across many people.  Then went into skincare and I'm obsessed.  Thank you for introducing me to Timeless - I love this.  OMGosh the Synthe' 6 diminished the crow's feet I had on my upper cheek!  Amazing.  I have also found your videos informative.  Keep up the good work!",
#   '🌸I am your day one. I was watching when you just had like 30 viewers.🤦🏻\u200d♀️ so many products getting confused 🌸🌺 not your fault am just getting old. I love all the research you do, so I don’t have to. I love you, Angie. You’re the best.',
#   'I am your day one. I was watching when you just had like 30 viewers.🤦🏻\u200d♀️ so many products getting confused 🌸🌺 not your fault am just getting old.',
#   'Angie I’ve been watching your videos for some time. I love your honest reviews and how spot on you are about products.  I tend to like what you like.  Your skin is flawless and you are age defying!  I know you talk about targeting  fine lines and wrinkles but have you ever had issues with lip lines or sagging jowls?  It doesn’t appear that you ever have.  But if so, can you share if there are things (products or treatments) that work for these issues? These are my biggest concerns and was hoping you could make some videos that address them. Thank you for your years of investing in mature skin and sharing your journey with us!!',
#   'I wanna try estriol cream one day but the chance of it causing melisma is what’s putting me off so like unless the results are in office procedure levels of dramatic, Idk. Im too scared lol',
#   "a doctor recommended AmLactin 12% lactic acid and It's WONDERFUL.",
#   'How can you find a reputable person to inject botox? Eyes, forehead, and so something with my marionet lines.',
#   'Angie...love your clips... What are these wonder cloths you use? Thanks!',
#   "You are the only Youtuber that I trust and I use your skincare for 5 years now and my skin looks great. I tried another products but I always go back to your skincare routine because it's the best. I'm 40 now and I started to become sensitive to tretinoin but mostly on my neck, what neck cream you recommend to help with aging and wrinkles?! Thx❤",
#   'Can you please reply with the (too ona orbital cleansing brush) coupon code. I can’t locate that anywhere in your notes or description and would love to purchase either your code. Thank you for the great content you share I’m a big fan of you and your videos',
#   'Angie I would have never guessed you started skincare at 50 by the way you have looked the past several years I have watched you! God bless yah! 🤗🤍',
#   'Wow you look great for your age!! But really, too many products and devices for me. What would you say are the top 3 must haves for someone like me with budget constraints. 😅 I am 51.'],
#  'Lbryrn5BhUo': ['Woah your so helpful I never knew this pin please as a birthday gift Xx',
#   'Drunk elephant is not the best for kids…it has lots of harmful ingredient kids don’t need\n1) retinal\n2)salicylic acid\n3)hyaluronic acid\n4) pretty much any word that has acid in it\n\nIt’s not good for anyone not even adults/teens/elders',
#   'I have EXTREMELY sensitive skin and bubble made me break out in hives 😢\nAny other suggestions? (I’m in the age range of 12-15, just for a bit of help) 😊',
#   'THIS HELPED SO MUCH thxxx❤❤❤',
#   'Just the kids products progressively getting expensive',
#   'Why is the rental cream under kids…💀',
#   'i wont give my exact age but I’ll say im inbetween the 11-14 age, do I NEED a toner in my routine or is it just an add on? Like spf and cleanser is a need (for me) but serum is an add on for me',
#   'Is this skincare routine good or no am under 18.      1st Byoma cleanser 2nd Byoma  toner  3rd Avocado serums  glow recipe   4th drunk bubble moisturizer 5th sun bum sunscreen. And then I spray tower 28 on my face',
#   'For kids yk how u put the drunk elaphant can i use the lala retro whipped creamw one?',
#   'these are boycott',
#   'Gk and history stories',
#   '⚠⚠EVERYONE PLEASE READ!!:⚠⚠\nThis is misleading information!! The Drunk Elephant "Bora Bora Skin Barrier Repair Cream" is NOT for young skin! The cream is meant to repair damaged skin and young children DO NOT NEED THEIR SKIN TO BE REPAIRED!!! Also, the Glow Recipe Avocado Serum is also NOT meant for kids! Kids normally shouldn\'t be using serums and advanced products on their skin but if they want to, THE GLOW RECIPE SERUM WOULD NOT BE IT!!!\nJust wanted to let you all know in case you want to find safe products :)',
#   'Ok drunk elephant ain’t for kids',
#   'The drink elephant moisturiser I so expensive',
#   'But what about combination skin?',
#   "Hey so I have white discoloration on my arms that I THINK is sun damage, what should I do to fix discoloration, I'm tan other than these little patches only on my arms. Love your videos keep it up!",
#   'Hey, you brought up a picture of Timothée Chalamet',
#   'Gay',
#   'I’m pretty sure he is gay',
#   "I tried bubble. It's definitely not for acne... It works terribly"],
#  '7Lki-dn30xg': ['Went from  preepy to more preepy😅',
#   'I also have bombshell perfume from Victoria’s Secret. I have two of them.',
#   'I live this vid',
#   '62k likes ❤❤❤',
#   'Colorful to clear',
#   '😂❤❤❤❤❤',
#   'From \nρяєρρу ✨💅💗\nтσ\n𝑪𝒐𝒒𝒖𝒆𝒕𝒕𝒆 ⋆˚\xa0˚⋆\n♡✩',
#   'MeIW✨',
#   'I have the same victoria secret perfume',
#   'WHAT DOES 4+4 EQUAL???',
#   'Please gimme please please please please please please please please please please please please please pleas💅🏻',
#   'Im 11 and i hava sol de janeiro gisou lip oil gisou hair oil drunk elephant summer fridays and laneige',
#   'Preppy to Coquette!!!',
#   'I told u we needed more glitter"😂',
#   'I need that flowers recipe',
#   'Preppy to aesthetic😂',
#   'Fr',
#   'u do not need anti aging!!!',
#   'Can the gisou lip gloss or lip stick be for kids😅',
#   'Omg love that so astetic'],
#  '5dinVl7aCWQ': ['Is anua deep cleansing foam better than innisfree volcanic deep cleansing foam.. im really confused everyone has a different opinion. Some say anua is overhyped and innisfree is better. Please help me out',
#   'Do you use all this on a wet face?',
#   '❤❤❤❤❤❤',
#   'Do you mask or scrub your face or u just use this products?',
#   'Love how glowy your skin looks ❤',
#   'Is use coeasing form as a facewash?',
#   'what website did you get it please?',
#   'This is not for oily or acne prone skin please look at the ingredients',
#   'Can you tell me how to use today I received mine but I don’t know how to use should I wash of cleanser foam with water .thank you',
#   'Does it remove blackheads from cheeks and chin as well?',
#   'I bought it all from my local chemist here in Australia and idk how to use them so I wanted to watch videos and I found yours. Also I have a question, I have like still fresh pimples on my face, should I wait till they pop and then use it or should I just go ahead and use it over it? Thank you sis ❤ will wait for your reply',
#   'Hi , oily skin can use this product ❤',
#   'How long does these products last when using daily?',
#   'I only wear sunscreen no makeup at all. Do i need to oil cleanse first at night? Or can i simply just use the foaming cleanser?',
#   'How many times a week can I use the cleansing oil?',
#   'No after or before comparison was shown. Absolutely no use of this video you could have done that alone.',
#   'Is it also recommendable for guys?',
#   'Where to buy korean products? Can anyone tell',
#   'Can I just use the oil alone?',
#   'These products don’t work I feel like black people should really protect each and not promote products that can kill us it’s made in China it’s not Korean skincare'],
#  'Kd37BmjoMXA': ['*My mom came and asked me what I was watching…* 😭🙏',
#   'You know this works ❤',
#   'I literally can’t tell if he trolling💀',
#   'im suprised ur able to get tattoos',
#   'Makes me want a hotdog reeal bad',
#   'Wow, thats a magic. I see the glow afterwards. Thats the real natural regimen.❤❤❤❤❤❤❤❤',
#   'Men are so lucky, I scrub my face that hard , next day I am waking up to hyperpigmentation',
#   'Shea butter stinks',
#   'You’re doing too much to your skin. For most peoooe Black soap is too harsh to use on your face. And to follow it up with clay mask, it’s too exfoliating.',
#   'crazy i dont need any of this shit',
#   'Serious question. Would this type of treatment work on someone who is a different race/ethnicity? Or is it kind of like hair treatments where different products work better with different types of hair?',
#   'Love it❤',
#   'Bro switched teams',
#   'Why is he shaking',
#   'Na how tf you gain rights, lose them, gain them again and then lose them again bro',
#   'Dang you complexion is awesome 🎉🎉🎉🎉🎉🎉😂😂😂😂😂😂',
#   'Ur clean',
#   'Bro forgot his whole forehead',
#   'You need a skin barrier repair serum or something',
#   "So it's okay now to do white face you racist. f you"],
#  'rnPuXYUoDOA': ['💌Become the girl you’ve always dreamed of. Join the It Girl Academy for your ULTIMATE glow-up: https://www.skool.com/itgirlacademy/about',
#   'Ur skin is so shiny 😊',
#   'I really admire your creativity here.',
#   'does this apply for acne-prone combination skin?',
#   'I love your video! Thank you for liking and using Korean cosmetics Thanks to you, I think Korean cosmetics can be widely known!!',
#   'Nice ❤😊',
#   'I looked for reviews for the centella cleansing oil and foam and so much people said that it made them breakout so badly and made their skin burn after one use. I have combinaison skin and wanna try out centella cleansers but im so scared of breaking out 😭',
#   'Just finished watching this, and it was fantastic!',
#   'What should I purchase for combination skin that is acne-prone and has blackheads and open pores too and tiny bumps on forehead and chin?',
#   "Why is all her products new and it seems like she's just promoting Mixsoon....",
#   "@allison_baek I can't find the vitamin c powder anywhere. Could I use a liquid vitamin c serum as a substitute?",
#   "K-Beauty always provides the best skincare routine. I bought this product according to Mixsoon skincare routine, and it's soft and keeps my skin dry all day. I love the natural glow",
#   'Chat GPT sent me here😂❤',
#   'Skin care with easy methods ❤😊\nhttps://youtube.com/shorts/x9cGESER-ro?si=OsecwZW-h4qtNlT_',
#   'Skin care 😘😊\nhttps://youtube.com/shorts/x9cGESER-ro?si=OsecwZW-h4qtNlT_',
#   'They are natural beauty',
#   'Korean women actually use German products',
#   'what sunscreen do you use?',
#   '"Love how simple and effective your Korean skincare routine is! 🌸 As someone with combination skin, I totally appreciate the balance of hydration and oil control in your products. The results look amazing! Definitely going to try out some of the products you mentioned. Thanks for the awesome tips! 🙌💖 #KBeautyRoutine #CombinationSkin"',
#   'https://youtube.com/shorts/qiRj-_opJ0c?feature=shared'],
#  '9TOEiaaoHBY': ["Way to many products for the face and I'm sure they are not natural for the most part and expensive to boot...however it works for her her skin is fabulous ❤😊",
#   'Should I double cleanse if I have acne?',
#   "Gurrrllllll with all these products i can't apply all these plenty layers of products as i live in one of d hottest regions ..i will sweat it all outby d time i am done in d day",
#   "I'm 15 an I have a skincare routine when i put my lotion when i get ready for school and when i  finish taking my bath in the evening",
#   'Definitely my next video 😍thank you for sharing',
#   'Are any of these products on Amazon ?',
#   'I love your skin care routine New subscriber',
#   'Hey so you just brought me so much relief! I think I have melasma too but I had no clue what it was called. I have had it since I was a child and I thought I just had huge dark spots on my checks and no matter what I did it did not work to get rid of it I could only lighten it a bit but now that I know what it is I can target it better. I have been so  insecure about it for so long',
#   'Do you use the Paulas choice salicylic acid cleanser every night??',
#   'Do you use the Paulas choice salicylic acid cleanser every night??',
#   "For your morning routine, do you let your serums sit for a few minutes before applying your sunscreen, and then let your sunscreen sit for a few minutes before beginning your make-up? When I don't, my sunscreen and foundation pills.",
#   "This is a lot. Do ppl really do this daily?  I'm slacking. I've only been using face soap and lotion.  But I don't wear makeup",
#   'What is the pink facial brush in the beginning?.... i am not seeing a link',
#   "Do we still need to use cleansing oil morning and night if you didn't wear makeup on that day?",
#   'You are beautiful I am guess what my grandma has the same name as you🎉🎉🎉🎉❤❤',
#   'Lenore Gateway',
#   'Corkery Stravenue',
#   '0545 Parker Union',
#   'I agree that Luna is a must-have product. It feels amazing on my skin as it gently cleanses, and the vibrations are so relaxing. It’s the best part of my day-and-night skincare routine.😊',
#   'How did you learn how to take care of your skin'],
#  'PI2noQKlwR0': ['More videos like this please! 🙏🏼❤',
#   'The skin1004 ampoule is perfect for dry skin',
#   'I can’t understand what to pick \nDoes (more dry/more oily) meaning is my skin? Bc I thought all combination skin look oily',
#   'Centella is both for dry and oily skin',
#   'hi where can i buy legit ANUA products?',
#   '❤❤❤❤😊',
#   'What a lovely product❤️thanks for sharing it with us😍',
#   'Where to buy',
#   'OMG I have extra dry skin but I’ve been using all the oily products…. ARGHH I still have so much stock! I don’t know what to do now 😢😢😢',
#   'Can you do a combo glass skin for oilu skin',
#   'The anua oil and foam cleanser made  me break out really bad so mabe consider buying the mini version first so you know if suits your skin',
#   'I don’t understand',
#   'For any cream for oily skin, the Purito Mighty Bamboo Panthenol Cream should work well too because it’s for all skin types and it is lightweight!',
#   'Anyone with oily/combo skin black that has used the centella sunscreen to help me, is it make up friendly too?',
#   'according to me riceberry sunscreen has worked wonders.. over a span of 2 years i have tried lakme, joy, swiss beauty, lotus and many others suggested by various people but only riceberry from littlelextra has made a difference.. its conveniently available.. no white cast.. no side effects whatsoever and very effective.. i hope this helps',
#   'Does centella  the gold one cause acne for combination skin? Or shall I skip the T-zone area',
#   'Centella Hyalu-Cica sunscreen good for oily skin',
#   'Is this for women',
#   'These are very costly products',
#   'I have a question i have oily skin and its also sensitive can i use those from the oily side?'],
#  'psbo1iSsr6c': ['mosok q krng menakne uwong rice Coker  smoh ra sah omong tk tukokne dapur kering digaene seng di gae yo ra bingong ngono sek maki2 soko ngendi kui msu ra ko gonaku',
#   'the pink 😭💗 i lovee',
#   'I LOVEEEE PINK',
#   'Manooooo ❤❤😊',
#   '🌸',
#   'You look like the princess from princess diaries ❤❤',
#   '#whiteoncream has been a total game-changer for my skin! The bright, glass skin effect I’ve achieved makes me feel so confident, and my dark spots are diminishing steadily. Your videos are a constant source of inspiration—thank you for sharing your insights!',
#   'Pinkkkk q',
#   'I love this color you new? I love you your videos your profile and enething',
#   'quanto amo questi video cosi aesthetic',
#   '❤',
#   'I love your skin care routine',
#   'Slay❤',
#   'I love ur skincare routine and ur so pretty \U0001fa77\U0001fa77',
#   'Produk bagus',
#   "Apply the toner after wash you're face,but is good👍",
#   'Мне кажется  я стала зависемой изза  тнбя❤😂',
#   'Such a stunning packaging🙌 Thanks for sharing it😍',
#   'Pink is my favorite color',
#   'Pink no no no no white yes yes yes😂'],
#  'B3BKNUX2vBo': ['Hi',
#   'Pookie your an icon i watch you all the time❤❤❤',
#   'BRO MY NAME IS KENZIE!',
# ...
#   'my skin goes to shit in Japan because the water is harder than Melbourne water. I love Melbourne water, i think its top 5 cleanest drinking water in the world for a metropolitan city.',
#   'Good Morning from Pflugerville, Texas.'],
#  'm65TpSVZI4E': ['Congratulations Dr. Rakshita singh',
#   'Congratulations ❤❤❤❤',
#   'Dr.Rakshita congratulations 🎉',
#   'Charm 🧿',
#   'Congratulations doctor di 🎉❤ u are my inspiration 💌',
#   'Vishal megamart 😂',
#   'Proud of you mam',
#   'Congratulations ❤🎉',
#   'Congrats Dr Rakshita Singh🎉❤',
#   'Congratulations 🎉di  wish u a lot of success ahead ❤',
#   'I also want to experience that day❤❤',
#   '🥳🥳🥳🥳🥳🥳',
#   'Can anybody tell me how many years she studied after 12th .',
#   'Congratulations Dr. Rashita singh u r best',
#   'Literally goosebumps \nDream to a best doctor like you❤\nLove you  dr. Rakshita singh❤❤',
#   'Congrats 🎉👏 dii',
#   'Overacting Unlimited 🤡',
#   'Congratulations didi 🎉❤',
#   'Haryana me hug kyu ni kr sakte daughter ko',
#   'Congratulations diii you are my inspiration 🎉🎉🎉🎉🎉'],
#  'qO4s2NSBoGc': [],
#  'ZbXErZeW-Zo': ['Hello, I wonder what to do. Often when i wear sunscreen I get eczema or something in my face. White bumps like acne. What can I do? I wear SPF for sensitive skin. Recomendations?',
#   'Skin Aqua is amazing. My skins loves it and it protects my skin super well since I use retinoid daily. I also love the canmake skin mermaid sunscreen.',
#   'Abbey, this video is incredible and I\'m so grateful for all of the testing and details! I\'m one of those people who actually is super interested in hearing all of the details about every single product -- I\'ve seen a lot of them when I was on vacation in Tokyo/Seoul and had questions about each one of them. Plus, everyone\'s skin concerns and goals are different. For example, in the case of my super-oily skin, I specifically look for mattifying, water resistant sunscreens with zinc oxide but no white cast. Ever since my FAVORITE Skin Aqua Moisture Milk formula was discontinued, I\'m back on the hunt for the perfect sunscreen. \n\nI agree with some of the other viewers that hearing your top recommendations in each category would be great -- but I also feel like you could post a shorter "top Asian sunscreen recommendations" video for people who just want to click for answers. In my case, I want and love all the details here!',
#   'Wow! This was a marathon of sunscreen review goodness!  Thank you for taking the time to try all of these and for sharing your thoughts on them!',
#   'Your reaction to the Scinic text was me 🤣🤣',
#   'I just came back around to this video because I finally went through my last  SPF — excited for new recommendations!! \n\nThank you for all of your hard work!!💕💕',
#   'What is the best water resistant sunscreen?',
#   'I just ordered the IUNIK one based off of this video and got the new one with American filters from Amazon 💔 buyer beware!',
#   'Abbey! The darker hair! OMG your eyes POP and it suits you so beautifully. Hope you keep it awhile :)',
#   "Love the showdowns!! One request, for future price comparisons, the price per oz or ml would be super helpful since some of them come in pretty different sizes so price doesn't always capture the comparison!!",
#   'Excellent comprehensive review. Thanks for all your support work. 👏',
#   'Am I the only one who gets terrible pilling with the Haruharu one? I’ve tried changing my skin care, letting my skincare dry down fully, putting on smaller amounts at a time, and nothing works 😭',
#   'I would love to hear your reccomendations for sunscreens that are good for hot, humid weather and face sweating 😰 Is there anything out there that doesnt make your face feel like its suffocating?',
#   'I adore your less blonde hair color! Can you share what brand and colors you use to achieve this color ✨️ 💛',
#   "I wanted to know if there was a sunscreen out there made special for around the eyes. My eyes are incredibly sensitive and I have yet to find a face one that doesn't burn the skin around them. Do you have any suggestions?",
#   "Wow this has been one of the most comprehensive Asian sunscreen review i've seen, so big thank you for all the work you put into it😊🙏🏼💕 \n\nMy  favorites of all these are also the Scinic one, Cosrx (a recent find and instant love😍), BOJ rice version and the I'unik one although that one stings my eyes if i sweat or it somehow ends up in them. But i love the texture, finish (not matte but not crazy dewy), feel and moisturising quality in all of them. \n\nI also tend to stick to the budget options because you go through a standard 50ml tube in a snap and so have to repurchase frequently. That's why i havent tried for example The House of Hur, Tocobo, D'alba (expensive af👀) or the Make Prem ones although i might probably like them. \n\nBtw there is a fragrance free version of that Isehan sunkiller one, it's Isehan Kiss me mommy (ment for children apparently) but from what i've heard it's got basically the same texture and is similar in feel to the scinic one. Amanda (forgot her last name) here on youtube raves about it all the time and has a similar Korean sunscreen video up like this one.\n\nFrom all of these i'm most interested to try the Numbuzin, Verdio and maybe those Skin Aqua ones, although heavy amount of alcohol dries out my skin so i'm hesitant. Also wanna try that new BOJ aqua fresh one. I'm surprised of you're despriction of it cause other youtubers have described it pretty much the opposite, a more lightweight and not as dewy version of the og rice one😄 So wanna find out what's it all about and cause i like the og one so much!\n\nLastly, (i know this comment is a short novel but i'm very passionate about Asian sunscreen/cosmetics😁) as much as i love the brand Haru haru (their black rice toner & essence ahh❤) and i so wanted to love their sunscreen cause it's got the rice in it, no fragrance and everything seemed ideal but i was left underwhelmed by it for the same reasons you mentioned. It's too thick to my taste (compared to all the others mentioned) almost felt matte on my skin (i have a combo/mature 36 year old skin that needs hydration and moisture) and i find the pump bottle inconvinient since the consistency is so thick it's hard to get the right amount (the two finger method) out evenly...maybe i'm the only one who's bothered by this but anywhoo, sadly haven't repurchased that one since first trying it.\n\nKudos for those who made it to the end of this comment!!😂 i applaud you👏🏼💕",
#   'Awesome video - thank you for making this! I’m surprised you didn’t include Hada Labo as well, would love to know your thoughts on their UV Perfect SPF 50.',
#   "I have normal to dry skin and used Skin1004 Madagascar SPF and Isntree (the ones you showed) - I preferred Skin1004 more. However I did get some suntan and with that pigmentation with both of them in summer. Now I am trying Haruharu mineral spf and it dries me out pretty badly! \nI also use T'else - Red Orange Niacinamide Moisture Sun Cream SPF 50+ PA++++ but not sure it is good protection either - see a tiny bit of suntan line along the jawline and it is not summer yet...\nI am on the lookout for a nice mineral or hybrid spf without alcohol which would be nicely moisturizing. \nWill try the Mermaid one - sounded pretty good.\nGreat review! Thank you!",
#   'honestly the amount of detail abbey goes into for each product is sooooo my hyper fixation tea so i can watch hours of this \n\nthats why unpopular opinion: i understand wanting a summarized version at the end but lets be real, most people would skip to the end for that and all that hard work goes down the drain…. i don’t think its hard to take a little bit of notes and give back some effort to abbey especially as her subscriber for all the extensive research you’re all receiving from her (this is just like a lecture yall bc well…IT IS)\n\n(ps. i have ADHD so i’m also not the most focused person/student)\n\nrecommendation for viewers: \n\n1. look through the chapter breakdown of the video. it can help you find a specific sunscreen you’re interested in (maybe you can even decide whether you want a japanese or korean sunscreen to narrow it further) \n\n2. after that if you can’t focus, prioritize finish (this video is actually divided into categories of finish) and feel because i’d assume that’s the main things people look out for. don’t mind ingredients too much if you’re not ingredients-focused because abbey will point out potentially harmful ones anyway. \n\nthanks for all that you do, Abbey! i will always love your videos ❤',
#   'Abbey, Hemish newest version is now spf 50+ with pa++++. Think you’d like to know 😊'],
#  '2748dGVgDkw': ['Chinchin 請問armani 面霜定estee Lauder呢隻面霜好用啲呀？❤',
#   '請問可唔可以介紹torriden呀 你有冇試過佢地嘅產品',
#   '個個都買得起la mer 咩, 貴婦',
#   '我都被燒到😂\n等唔到四月，又買左野\nLa Mer lotion 新嘗試\n同埋四月想試 Fresh 支茶精華！',
#   '好想睇最update 面膜最愛😍',
#   '請問唇膏顏色？好靚❤',
#   '正呀',
#   'thank you for sharing Chin Chin!! love you',
#   'Chin chin 想問對於石頭瘡有冇咩方法解決🥵  成日生到腫咗一嚿搞唔掂😢',
#   '我買的Sisley磨砂膏是玻璃罐裝的。我覺得佢好粗粒，磨得有點痛。玻璃罐裝同你的膠樽裝是否有不同？',
#   '今年用咗Suqqu卸妝油，出奇地覺得好好用，同Three咁',
#   '請問chin chin 件衫在那裏可以買？',
#   '我都想買洗頭水呀😍😍請問你喺邊間剪頭髮？',
#   '又係好燒❤想問支body partner去patpat紋係咪都真係有效？',
#   '一直以黎對Estée Lauder無咩好感\n都同我吾係好夾\n但佢枝re-Nutriv 精華\n令到我對佢改觀左❤️',
#   'Chinchin 有冇用過Cle de peau 既洗面皂？同埋想問下針對虎紋有冇推薦產品？',
#   'Hello 芊芊，多謝你嘅誠推。請問 La Mer 個 Cream 為什麼size呢？',
#   '有中文字幕耶！！🤩感謝分享！！🥰',
#   '芊芊你每次介紹都好好...又令我心動去買你推展產品呀....hahah 😘😘😘😘',
#   'What happened to the video quality why is it only 720p? 😮'],
#  'HNNmTKmyTUc': [],
#  'FNpt4riezQA': ['nahh..its an example of same face, different angle, different lighting and different facial expression',
#   'If you’re extra nervous about using any eyeliner. You can use eyeshadow in place of eyeliner :) I do that on days I’m rushing and setting spray would keep it from moving all day',
#   'Hey! My concealer actually has both aqua (water) and cyclopenyasiloxane, so is it water based or silicone based?',
#   'Unfortunately the App is not in Germany',
#   'when i started wearing make up in 6th grade i just put dark powder on my face hoping it will cover my pimpels',
#   'i am so happy bc i need this i am so happy this pot up  on my ryp',
#   'ii feel like i actually understood something and learned from tthis so thank you sm.. usually in makeup videos im TOTALLY LOST and i end up looking terrible so seriously thank u thank u thank u',
#   "I think it's just hairstyle and angle of camera \nNo hate but both make up looks very similar",
#   "Guys, I'm an Indian and I just tried this, it looks amazing. just use your colours.❤",
#   "I love this! But I NEED to know what contacts you're wearing 😍",
#   "ppl with thick brows are blessed, mine don't even show😭🙏🏻",
#   'aaaaa... how cool! finally found a blogger t=who suits me and does everything in my style! I adore this kind of makeup with plump lips! Maybe someone can tell me where to finish makeup courses in Paris?',
#   'I appreciate the cheaper recommendations, like no one really does those',
#   'OHHH THATS WHAT THE PILLING IS',
#   'is anyone else flabbergasted that this is considered a daily makeup look??? yall are busting out contouring for your nine to five??',
#   'Im NOT a kid i posr my sisters  ids but while doing the under lashes at 12:10  i got mascara in my eye 😢',
#   'what age is best to start using makeup?? cuz its almost my b-day and my parents said if im old enough than i could get makeup :)))) (im turning 13 btw)',
#   'I have naturally dark eyebrows! What should I do??',
#   'I went into this tutorial with just a blush and eyeshadow TT This is really helpful :)',
#   'Thank you so much, I wish you went to to depth on your aegyo sal because I am mixed, my eyes are more similar to yours than most tutorials I found 😢'],
#  '5x11nhTCNZM': ['MEU DEUS QUE COLAR PERFEITOOOOO',
#   'Faz um vídeo de dicas de viagem internacional, em aeroporto, como viajar só c uma mala de mão, e item pessoal',
#   'lari uma dica, quando você for em restaurante mostra mais o cardápio, valor que deu sua conta etc!!',
#   'Lari eu também esqueço tudo de Harry hahahahahahahahhaah é sempre mágico!!!',
#   'Que colar mais lindo é esse 😻',
#   'Amo natal ❤. E ano novo 🥳🎉',
#   'Meu aniversário também é em Dezembro e eu sou apaixonada por esse mês tão especial. ❤❤',
#   'best vlogs always',
#   'Eu me sinto tão representada com o seu amor e encantamento pelo mês de dezembro! Vc é uma pessoa muito especial que ilumina o mundo sendo apenas vc mesma! ❤',
#   'Biaaaa!\nEu amo ver vocês as duas.\nA vossa amizade é linda e vocês são tão fofas.\nAmigas para sempre.❤❤❤',
#   'Uma paz assistir seus vídeos ❤',
#   'Amo seus vlogs lari❤ são muito aconchegantes de assistir!❤',
#   'Lari qual gloss você usou ? Ficou perfeito',
#   'O “nuuu” pra dizer que algo está muito bom é a personificação do ser mineiro! 😂🤩',
#   'amiga sim, a amnésia de harry potter é real, sendo que eu li e assisti várias vezes KKKKK',
#   'Gente qual o nome do filme q elas tavam vendo????',
#   'Vídeos conforto depois de um dia cansativo ❤❤❤',
#   'Feliz Natal!! Jesus nasceu aleluia!❤❤',
#   'Vc me da muita vnt de morar em NY juro, mas eu sempre vejo videos mostrando que aí e muito perigoso e tals, e inclusive algo que eu reparei e que vc n mostra esse lado mais sombrio dai',
#   '❤❤❤❤❤'],
#  '32CS1FH_ZHI': [],
#  'zRcG1kYFtXI': [],
#  'n3g5wR8ySAw': ['0:09',
#   "Hi, can you make a video about the curly girl method - is it a safe method to be used as no shampoo is used, only conditioners. I am following cgm for 2 months now and my scalp gets very greasy quite quickly, but it was greasy before the cgm too and I have a 2b and 2c type curls - it was greasy on my scalp and I had dry ends of my hair. I can see that cgm helps my hair but not to a scalp.. Lots of cgm followers told me it's a natural process as my hair was used to sulphate shampoos with harsh ingredients and it might even take 6 months until my scalp ''calms down'' - is that true? Thank you in advance :)",
#   'Thank you ladies for this video. Can you post more video for black and brown hair care tips There is not enough information on hair care for the black community. Can we get more insight on shampoo, conditioner, oils etc.',
#   'the music is really annoying / too loud',
#   '3:28 ✔️ *Top SLOTS WIN* https://youtu.be/pjYRAA0kGrc',
#   '👍🏾✔'],
#  'd2-af2Fifbw': ['Please subscribe my channel for more skin care video \nThankyou'],
#  'ud_z_fBszeo': ['Juat heaed about this movie and watched it for the first time. Remarkable! Great movie!',
#   'This looks adoringly like a Hallmark movie but without all the extra cheese.  Maybe a little extra sap though...',
#   'Great movie and storyline!  ❤',
#   'This is such a beautiful film ❤',
#   'STORY OF MY LIFE?????\nAHHHHHHHH',
#   'This bullshit soft core porn movie was sooooooo beautiful \n\n\nIreland always looks like this ! Fecking adorable!!!!\n\nAnd special UPDATE ! FOR 2024 : gr8 news kids ! \n\nNow just sprinkle 10 million recently arrived Muslim and African illegal immigrants ALL OVER TOWN FOR ADDED REALITY EFFECT! The irish have welcomed them with open arms !\n\nTheyre THRILLED 😂\n\nTHX NEW WORLD ORDER ❤',
#   'This movie broke my heart and then lifted me back up again ❤ so worth renting it ❤ definitely gonna be a re watch type of movie ❤',
#   'What song was that at the end with Finley in the graveyard looking at the cross?',
#   'My new favorite movie♥️ it was so beautiful',
#   'Good movie, but a lot of symbolism in it !',
#   'Toubtube',
#   'This is movie I have never seem , keep up the great work You Tube',
#   'As A young Man of 86 years, I have viwed many a fine movies, but by far this is the best  and the most often viewed by me.  Thank the whole cast. especially Rose Reid.',
#   "It's not working",
#   'This movie was sweet ❤️',
#   'It comes out on Amazon on July 26th I believe',
#   'Miss seeing this movie in the theater so I am looking forward to getting the DVD when it comes out.  Looks like such a charming, sensitive, funny, & romantic movie.  The kind I so love!!   😍❤️💕',
#   'When does this come our',
#   'When does this come out',
#   'Sixth 😀']}
